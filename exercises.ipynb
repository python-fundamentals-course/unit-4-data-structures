# %% [markdown]
# # Unit 4: Data Structures — Exercises
#
# > **Python Fundamentals**
#
# Complete the reading materials, curated videos, and `notebook.ipynb` before working through these exercises.

# %% [markdown]
# ## Learning objectives
#
# By the end of this unit you will be able to:
#
# - Choose the right data structure for a given task
# - Use the list-of-dicts pattern to represent tabular data
# - Apply list comprehensions and dict operations to process data

# %% [markdown]
# ## Exercise 1: Lists
#
# Starting from `books`:
#
# 1. Add `"The Pragmatic Programmer"` to the end of the list
# 2. Remove `"Old Manual"` from the list
# 3. Sort the list alphabetically (in place)
#
# Print the list before and after each step.

# %%
books = ["Clean Code", "Old Manual", "Fluent Python"]

print("Start:", books)

# TODO: 1. append "The Pragmatic Programmer"

# TODO: 2. remove "Old Manual"

# TODO: 3. sort the list

# %% [markdown]
# ## Exercise 2: Tuples and unpacking
#
# `results` is a list of `(name, score)` tuples. Loop over it, unpacking each tuple into `name` and `score`, and print `"<name> scored <score>"` for each.

# %%
results = [("Alice", 85), ("Bob", 72), ("Carol", 91)]

# TODO: loop over results, unpacking each tuple, and print the message

# %% [markdown]
# ## Exercise 3: Sets — comparing two workshops
#
# `workshop_a` and `workshop_b` are lists of attendee names for two workshops. Calculate:
#
# 1. `both` — attendees who went to **both** workshops (intersection)
# 2. `only_one` — attendees who went to **only one** workshop (symmetric difference)
# 3. `total_unique` — the **total number** of unique attendees across both workshops (union)
#
# Print all three.

# %%
workshop_a = ["Alice", "Bob", "Carol", "Dan"]
workshop_b = ["Carol", "Dan", "Eve", "Frank"]

# TODO: 1. both - intersection of the two sets

# TODO: 2. only_one - symmetric difference

# TODO: 3. total_unique - size of the union

# %% [markdown]
# ## Exercise 4: Dicts, comprehensions, and the list-of-dicts pattern
#
# `employees` is a list of dicts, each with `name`, `department`, and `salary`. Calculate:
#
# 1. `engineering_names` — a list of names of employees in the `"Engineering"` department (use a list comprehension)
# 2. `salary_by_department` — a dict mapping each department to the **total** salary for that department
# 3. `top_earner` — the name of the employee with the highest salary (*hint: use `max()` with a `key=` function*)

# %%
employees = [
    {"name": "Alice", "department": "Engineering", "salary": 7000},
    {"name": "Bob", "department": "Sales", "salary": 5000},
    {"name": "Carol", "department": "Engineering", "salary": 8000},
    {"name": "Dan", "department": "Sales", "salary": 5500},
    {"name": "Eve", "department": "Marketing", "salary": 6000},
]

# TODO: 1. engineering_names - list comprehension

# TODO: 2. salary_by_department - dict of totals

# TODO: 3. top_earner - name of the highest-paid employee

# %% [markdown]
# ## Done?
#
# Run the tests (`pytest tests/ -v`) to check whether your answer is correct. Your solution doesn't need to match any particular approach, as long as it produces the right results — your trainer can walk through worked solutions in class.
